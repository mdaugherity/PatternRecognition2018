# %% [markdown]
# Type in text here

# %%
print ("Hello world")
# Out:
# Hello world

# %%
x = 2
x + 4
# Out:
# 6

# %% [markdown]
# Rachael was here

# %%
But - did she use a bunch of arcane Git CLI commands to get here?  I THINK NOT.
- Kevin Shurtz
